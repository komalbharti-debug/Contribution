# %% [markdown]
# <a href="https://colab.research.google.com/github/komalbharti-debug/Contribution/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    dist = {node: float('inf') for node in graph}
    parent = {node: None for node in graph}
    visited = []

    dist[start] = 0

    while len(visited) < len(graph):
        min_node = None

        for node in graph:
            if node not in visited:
                if min_node is None or dist[node] < dist[min_node]:
                    min_node = node

        visited.append(min_node)

        for neigh, wt in graph[min_node].items():
            if dist[min_node] + wt < dist[neigh]:
                dist[neigh] = dist[min_node] + wt
                parent[neigh] = min_node

    return dist, parent


def get_path(parent, node):
    path = []
    while node:
        path.append(node)
        node = parent[node]
    return path[::-1]


# 🔹 INPUT (easy way)
nodes = input("Enter nodes (space separated): ").split()

graph = {}

for node in nodes:
    graph[node] = {}
    neighbors = int(input(f"Number of neighbors of {node}: "))

    for _ in range(neighbors):
        n, w = input("Enter neighbor and weight: ").split()
        graph[node][n] = int(w)


start = input("Enter source: ")

dist, parent = dijkstra(graph, start)

print("\nResult:")
for node in nodes:
    path = get_path(parent, node)
    print(start, "->", node, "=", dist[node], ", Path:", "->".join(path))
# Out:
# Enter nodes (space separated): a b c d e
# Number of neighbors of a: 2
# Enter neighbor and weight: b 4
# Enter neighbor and weight: c 2
# Number of neighbors of b: 2
# Enter neighbor and weight: a 4
# Enter neighbor and weight: d 5
# Number of neighbors of c: 3
# Enter neighbor and weight: a 2
# Enter neighbor and weight: b 5
# Enter neighbor and weight: d 3
# Number of neighbors of d: 1
# Enter neighbor and weight: c 3
# Number of neighbors of e: 1
# Enter neighbor and weight: d 6
# Enter source: a
#
# Result:
# a -> a = 0 , Path: a
# a -> b = 4 , Path: a->b
# a -> c = 2 , Path: a->c
# a -> d = 5 , Path: a->c->d
# a -> e = inf , Path: e
